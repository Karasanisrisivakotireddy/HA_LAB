# %%
print("koti reddy")
# Out:
# koti reddy

# %%
if 5>6:
  print("koti")
else:
  print("koti reddy")
# Out:
# koti reddy

# %%
k=2
o=2.11
t=55555555552222222222222222222222222222222222222222222222222222
i=556+6j
print(k,o,t)
print(type(k),type(o),type(t),type(i))
print(type(k))
print(type(o))
print(type(t))
print(type(i))
# Out:
# 2 2.11 55555555552222222222222222222222222222222222222222222222222222
# <class 'int'> <class 'float'> <class 'int'> <class 'complex'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
print(6*8)
print(5>>3)
print(88>433)
print(111+111)
print(9==2)
print(5%2)
print(5/2)
print(2^3)
print(50!=3)
print(2==2)
print(2!=2)
a=2.22
b=2233
print(a+b)
print(type(a+b))
# Out:
# 48
# 0
# False
# 222
# False
# 1
# 2.5
# 1
# True
# True
# False
# 2235.22
# <class 'float'>

# %%
a=4
a+=1
print(a)
k=8+1
print(k)
o=22
o-=1
print(o)
t=555
t%=11
print(t)
i=10
i/=12
print(i)
r=11111222
r*=2
print(r)
# Out:
# 5
# 9
# 21
# 5
# 0.8333333333333334
# 22222444

# %%
k=1112212
print(k>292929292929 or k>36353535)
print(k<8484848 or k<1616)
print(k<484848 and K<474646446)
print(k>3636436 and k>484847447)
# Out:
# False
# True
# False
# False

# %%
k=44
o=4453
t=22
i=22
print(k is o)
print(k is not o)
print(t is i)
print(t is not i)
# Out:
# False
# True
# True
# False

# %%
k=33
o=[11,22,33]
print(k in o)
print(k not in o)
# Out:
# True
# False

# %%
k=12
o=12
print(id(k))
print(id(o))
# Out:
# 11654728
# 11654728

# %%
k=17
o=226
print(k|o)
print(k&o)
print(k^o)
print(~k)
print(~o)
print(k>>o)
print(k<<o)
print(o>>k)
print(o<<k)
# Out:
# 243
# 0
# 243
# -18
# -227
# 0
# 1833276373366243506037357025917334885807325820732758928715045496946688
# 0
# 29622272

# %%
print(1+2*5)
print((1+2)*5)
print(1*2**5)
print(1*2*2*2*2)
# Out:
# 11
# 15
# 32
# 16

# %%
print(7373737/0)
print(7373737//0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-811531709.py in <cell line: 0>()
# ----> 1 print(7373737/0)
#       2 print(7373737//0)
#
# ZeroDivisionError: division by zero

# %%
k=[28,17,66,"koti",'reddy']
print(k)
print(type(k))
print(k[0])
print(k[1])
print(k[2])
print(k[3])
print(k[4])
print(k[-1])
print(k[-2])
print(k[-3])
print(k[-4])
print(k[-5])
# Out:
# [28, 17, 66, 'koti', 'reddy']
# <class 'list'>
# 28
# 17
# 66
# koti
# reddy
# reddy
# koti
# 66
# 17
# 28

# %%
k=[28,17,66,"koti",'reddy']
print(k)
print(k[0:1])
print(k[0:2])
print(k[0:3])
print(k[0:4])
print(k[0:5])
print(k[0:6])
print(k[0:])
print(k[1:])
print(k[2:])
print(k[3:])
print(k[4:])
# Out:
# [28, 17, 66, 'koti', 'reddy']
# [28]
# [28, 17]
# [28, 17, 66]
# [28, 17, 66, 'koti']
# [28, 17, 66, 'koti', 'reddy']
# [28, 17, 66, 'koti', 'reddy']
# [28, 17, 66, 'koti', 'reddy']
# [17, 66, 'koti', 'reddy']
# [66, 'koti', 'reddy']
# ['koti', 'reddy']
# ['reddy']

# %%
k=[28,17,66,"koti",'reddy']
print(k)
o=[12,16,35,"koti",33]
print(o)
print(k+o)
print(o[1:]*2)
# Out:
# [28, 17, 66, 'koti', 'reddy']
# [12, 16, 35, 'koti', 33]
# [28, 17, 66, 'koti', 'reddy', 12, 16, 35, 'koti', 33]
# [16, 35, 'koti', 33, 16, 35, 'koti', 33]

# %%
k=(91,2,3)
o=(733,2,4)
print(k)
print(o)
t=k+o
print(t)
i=k*5
print(i)
# Out:
# (91, 2, 3)
# (733, 2, 4)
# (91, 2, 3, 733, 2, 4)
# (91, 2, 3, 91, 2, 3, 91, 2, 3, 91, 2, 3, 91, 2, 3)

# %%
k="koti"
o="reddy"
print(k+o)
print(k[0])
print(k[0:2])
print(o[:2])
print(type(k))
print(type(o))
print(type(k+o))
# Out:
# kotireddy
# k
# ko
# re
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
k="koti"
o="reddy"
t=k+"3"
i=o+"3"
r=k*2
print(k)
print(o)
print(t)
print(i)
print(r)
# Out:
# koti
# reddy
# koti3
# reddy3
# kotikoti

# %%
k="koti"
o="reddy"
print(k.upper)
print(k.capitalize)
print(k.lower)
print(o.upper)
print(o.capitalize)
print(o.lower)
# Out:
# <built-in method upper of str object at 0x7818cedea490>
# <built-in method capitalize of str object at 0x7818cedea490>
# <built-in method lower of str object at 0x7818cedea490>
# <built-in method upper of str object at 0x7818cedeb3c0>
# <built-in method capitalize of str object at 0x7818cedeb3c0>
# <built-in method lower of str object at 0x7818cedeb3c0>

# %%
a={12,12,24,456}
b={21,43456,88,"koti reddy"}
print(a)
print(b)
print(type(a))
# Out:
# {24, 12, 456}
# {43456, 88, 21, 'koti reddy'}
# <class 'set'>

# %%
a={12,12,24,456}
b={21,43456,88,"koti reddy"}
for k in a:
  print(b)
# Out:
# {43456, 88, 21, 'koti reddy'}
# {43456, 88, 21, 'koti reddy'}
# {43456, 88, 21, 'koti reddy'}

# %%
a={12,12,24,456}
b={21,43456,88,"koti reddy"}
print(a|b)
print(a&b)
print(a^b)
print(a-b)
# Out:
# {43456, 'koti reddy', 21, 456, 24, 88, 12}
# set()
# {43456, 'koti reddy', 456, 12, 21, 24, 88}
# {24, 12, 456}

# %%
a={12,12,24,456}
b={21,43456,88,"koti reddy"}
